# %% [markdown]
# # Model Evaluation: 2016 US Election
#
# This notebook runs the Multilevel Regression and Post-stratification (MRP) pipeline for the 2016 US Presidential Election and compares the results against actual outcomes and PredictIt prediction markets.

# %%
from bias_analysis.modeling.train import main
from bias_analysis.plots import generate_mrp_dashboard

ELECTION = "us16"

print(f"--- Running MRP Pipeline for {ELECTION} ---")
main(election=ELECTION)

print(f"\n--- Generating Dashboard and Metrics for {ELECTION} ---")
generate_mrp_dashboard(election=ELECTION)
# Out:
# 2026-04-21 18:37:21.993 | INFO     | bias_analysis.config:<module>:11 - PROJ_ROOT path is: C:\Users\utente\Desktop\Work\TweetPollBias
# --- Running MRP Pipeline for us16 ---
# 2026-04-21 18:37:23.782 | INFO     | bias_analysis.dataset:get_base_dataset:351 - Loading cached base dataset from C:\Users\utente\Desktop\Work\TweetPollBias\data\processed\us16\base_dataset_cache.pkl
# 2026-04-21 18:37:23.809 | INFO     | bias_analysis.modeling.train:load_and_merge_features:139 - Merged dataset: 761 polls, 36 columns
# 2026-04-21 18:37:23.810 | INFO     | bias_analysis.modeling.train:main:236 - Analysis-ready polls: 761
# 2026-04-21 18:37:23.828 | INFO     | bias_analysis.modeling.train:main:243 -
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         positive_share   No. Observations:                  761
# Model:                            GLM   Df Residuals:                   201603
# Model Family:                Binomial   Df Model:                            8
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -86697.
# Date:                Tue, 21 Apr 2026   Deviance:                       19185.
# Time:                        18:37:23   Pearson chi2:                 1.94e+04
# No. Iterations:                     4   Pseudo R-squ. (CS):              1.000
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -0.9308      0.024    -38.887      0.000      -0.978      -0.884
# audience_mean_partisanship     0.9390      0.009    104.851      0.000       0.921       0.957
# author_partisanship            0.0791      0.008     10.054      0.000       0.064       0.094
# candidate_order                0.4220      0.020     21.075      0.000       0.383       0.461
# formality_bias                 0.0160      0.010      1.615      0.106      -0.003       0.035
# positive_ideology_score        0.3607      0.041      8.790      0.000       0.280       0.441
# author_gender_male            -0.0511      0.021     -2.475      0.013      -0.092      -0.011
# author_age_30_39               0.1827      0.036      5.134      0.000       0.113       0.252
# author_age_40_over             0.3593      0.022     16.377      0.000       0.316       0.402
# ==============================================================================================
# 2026-04-21 18:37:23.831 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 1.0000
# 2026-04-21 18:37:23.847 | INFO     | bias_analysis.modeling.train:main:249 -
# Post-stratification predictions per stratum:
# 2026-04-21 18:37:23.847 | INFO     | bias_analysis.modeling.train:main:251 -     Republican × Conservative    weight=0.1155  pred_trump=0.6927
# 2026-04-21 18:37:23.847 | INFO     | bias_analysis.modeling.train:main:251 -     Republican × Moderate        weight=0.1287  pred_trump=0.6907
# 2026-04-21 18:37:23.847 | INFO     | bias_analysis.modeling.train:main:251 -     Republican × Liberal         weight=0.0858  pred_trump=0.6887
# 2026-04-21 18:37:23.847 | INFO     | bias_analysis.modeling.train:main:251 -       Democrat × Conservative    weight=0.1260  pred_trump=0.5910
# 2026-04-21 18:37:23.847 | INFO     | bias_analysis.modeling.train:main:251 -       Democrat × Moderate        weight=0.1404  pred_trump=0.5906
# 2026-04-21 18:37:23.847 | INFO     | bias_analysis.modeling.train:main:251 -       Democrat × Liberal         weight=0.0936  pred_trump=0.5902
# 2026-04-21 18:37:23.847 | INFO     | bias_analysis.modeling.train:main:251 -    Independent × Conservative    weight=0.1085  pred_trump=0.5979
# 2026-04-21 18:37:23.848 | INFO     | bias_analysis.modeling.train:main:251 -    Independent × Moderate        weight=0.1209  pred_trump=0.5969
# 2026-04-21 18:37:23.848 | INFO     | bias_analysis.modeling.train:main:251 -    Independent × Liberal         weight=0.0806  pred_trump=0.5960
# 2026-04-21 18:37:23.848 | INFO     | bias_analysis.modeling.train:main:260 -
# 2026-04-21 18:37:23.848 | INFO     | bias_analysis.modeling.train:main:261 - ======================================================================
# 2026-04-21 18:37:23.848 | INFO     | bias_analysis.modeling.train:main:262 - RESULTS SUMMARY
# 2026-04-21 18:37:23.848 | INFO     | bias_analysis.modeling.train:main:263 - ======================================================================
# 2026-04-21 18:37:23.848 | INFO     | bias_analysis.modeling.train:main:265 -   Raw Unweighted Average (Trump %) : 52.18%
# 2026-04-21 18:37:23.848 | INFO     | bias_analysis.modeling.train:main:266 -   Vote-Weighted Average  (Trump %) : 62.02%
# 2026-04-21 18:37:23.848 | INFO     | bias_analysis.modeling.train:main:267 -   MRP Adjusted Estimate  (Trump %) : 62.57%
# 2026-04-21 18:37:23.849 | INFO     | bias_analysis.modeling.train:main:268 -   Actual Result          (Trump %) : 56.8%
# 2026-04-21 18:37:23.849 | INFO     | bias_analysis.modeling.train:main:271 -   Exit-Poll Deviation              : +5.77 pp
# 2026-04-21 18:37:23.849 | INFO     | bias_analysis.modeling.train:main:273 -
# 2026-04-21 18:37:23.849 | INFO     | bias_analysis.modeling.train:main:274 -   Prediction Market Reference: Placeholder Market
# 2026-04-21 18:37:23.849 | INFO     | bias_analysis.modeling.train:main:277 -     Trump win probability: 20%
# 2026-04-21 18:37:23.849 | INFO     | bias_analysis.modeling.train:main:277 -     Clinton win probability: 80%
# 2026-04-21 18:37:23.849 | INFO     | bias_analysis.modeling.train:main:278 -     Note: Placeholder win-probability estimates for 2016.
# 2026-04-21 18:37:23.849 | SUCCESS  | bias_analysis.modeling.train:main:280 - MRP pipeline completed successfully.
#
# --- Generating Dashboard and Metrics for us16 ---
# 2026-04-21 18:37:23.853 | INFO     | bias_analysis.plots:generate_mrp_dashboard:946 - Loading data and fitting global GLM for MRP dashboard [us16] …
# 2026-04-21 18:37:23.854 | INFO     | bias_analysis.dataset:get_base_dataset:351 - Loading cached base dataset from C:\Users\utente\Desktop\Work\TweetPollBias\data\processed\us16\base_dataset_cache.pkl
# 2026-04-21 18:37:23.876 | INFO     | bias_analysis.modeling.train:load_and_merge_features:139 - Merged dataset: 761 polls, 36 columns
# 2026-04-21 18:37:23.877 | INFO     | bias_analysis.plots:generate_mrp_dashboard:957 - Analysis-ready polls: 761
# 2026-04-21 18:37:23.890 | INFO     | bias_analysis.plots:generate_mrp_dashboard:965 - Global GLM fitted successfully.
# 2026-04-21 18:37:23.895 | INFO     | bias_analysis.plots:generate_mrp_dashboard:986 - Date range: 2016-01-05 → 2016-11-08
# 2026-04-21 18:37:23.930 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:23.944 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:23.956 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:23.969 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:23.985 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:23.999 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.012 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.026 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.041 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.054 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.069 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.082 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.096 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.114 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.127 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.138 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.151 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.164 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.178 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.191 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.204 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.222 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.234 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.246 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.258 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.271 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.285 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.302 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.315 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.328 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.344 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.357 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.372 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.385 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.399 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.411 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.423 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.435 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.447 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.472 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.489 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.501 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.513 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.530 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.542 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.553 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.565 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.576 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.590 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.607 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.621 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.640 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.669 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.685 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.699 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.711 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.722 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.734 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.753 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.764 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.776 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.788 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.801 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.813 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.827 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.839 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.853 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.879 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.891 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.904 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.916 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.928 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.939 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.951 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.962 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.974 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.986 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:24.997 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.010 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.021 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.033 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.044 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.056 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.067 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.079 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.090 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.102 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.114 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.126 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.138 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.155 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.166 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.178 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.190 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.201 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.213 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.226 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.237 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.249 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.261 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.273 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.288 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.300 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.311 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.332 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.344 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.364 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.375 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.387 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.398 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.411 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.423 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.434 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.446 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.458 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.470 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.483 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.495 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.507 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.519 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.531 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.543 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.555 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.567 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.579 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.591 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.604 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.616 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.627 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.639 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.651 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.662 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.673 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.685 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.697 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.708 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.720 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.732 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.743 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.755 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.768 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.781 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.792 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.804 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.815 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.827 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.839 | INFO     | bias_analysis.modeling.train:build_poststrat_frame:209 - Post-stratification frame: 9 strata, total weight = 0.9900
# 2026-04-21 18:37:25.847 | INFO     | bias_analysis.plots:generate_mrp_dashboard:1026 - Computed 147 daily data points for the dashboard.
# 2026-04-21 18:37:25.847 | INFO     | bias_analysis.plots:generate_mrp_dashboard:1033 - Loading PredictIt data from C:\Users\utente\Desktop\Work\TweetPollBias\data\raw\predictit\us16.csv
# 2026-04-21 18:37:25.914 | SUCCESS  | bias_analysis.plots:generate_mrp_dashboard:1064 - Loaded 264 PredictIt daily records for Trump vs Clinton.
# 2026-04-21 18:37:26.227 | SUCCESS  | bias_analysis.plots:generate_mrp_dashboard:1217 - Interactive dashboard saved to C:\Users\utente\Desktop\Work\TweetPollBias\reports\us16\mrp_bias_dashboard.html
# 2026-04-21 18:37:26.227 | INFO     | bias_analysis.plots:generate_mrp_dashboard:1221 - MRP Estimate MAE vs Actual Result (across all days): 6.21 pp
# 2026-04-21 18:37:26.228 | INFO     | bias_analysis.plots:generate_mrp_dashboard:1229 - PredictIt Market MAE vs Actual Result (across all market days): 26.03 pp
# 2026-04-21 18:37:26.229 | INFO     | bias_analysis.plots:generate_mrp_dashboard:1235 - Mean Divergence (MAE) between MRP and PredictIt: 30.21 pp
#           date  raw_trump  raw_clinton  mrp_trump  mrp_clinton  n_polls
# 0   2016-02-19   0.344048     0.655952   0.468726     0.531274        3
# 1   2016-02-20   0.344048     0.655952   0.468726     0.531274        3
# 2   2016-02-21   0.344048     0.655952   0.468726     0.531274        3
# 3   2016-02-22   0.498337     0.501663   0.567796     0.432204        5
# 4   2016-02-23   0.498337     0.501663   0.567796     0.432204        5
# ..         ...        ...          ...        ...          ...      ...
# 142 2016-11-04   0.599650     0.400350   0.657111     0.342889       25
# 143 2016-11-05   0.601981     0.398019   0.638990     0.361010       28
# 144 2016-11-06   0.595684     0.404316   0.634341     0.365659       29
# 145 2016-11-07   0.558634     0.441366   0.629021     0.370979       39
# 146 2016-11-08   0.550186     0.449814   0.619155     0.380845       58
#
# [147 rows x 6 columns]

# %% [markdown]
# ## Evaluation Insights
#
# ### Head-to-Head Accuracy vs. Actual Result
# - **MRP MAE vs Actual**: 6.21 pp
# - **PredictIt MAE vs Actual**: 26.03 pp
# - **Mean Divergence (MRP vs Market)**: 30.21 pp
#
# ### Analysis
# In 2016, the **MRP model significantly outperformed the prediction markets**. While PredictIt prices remained heavily skewed toward a Clinton landslide (leading to a massive 26.03 pp error relative to the final result), the MRP-adjusted Twitter polls captured the tighter reality of the race much better.
#
# This case illustrates how markets can sometimes be slower to correct for partisan 'received wisdom' than a demographic-weighting model that filters out social media echo chambers.
