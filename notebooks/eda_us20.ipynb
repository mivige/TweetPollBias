# %% [markdown]
# # Exploratory Data Analysis: 2020 US Election (Twitter)
#
# This notebook explores the Twitter poll dataset for the 2020 US Presidential Election.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from pathlib import Path

sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

import warnings
warnings.filterwarnings('ignore')

sys.path.append(str(Path('..').resolve()))
from bias_analysis.dataset import get_base_dataset

from loguru import logger
logger.remove()

# %% [markdown]
# ## 1. Load US20 Dataset

# %%
df = get_base_dataset(election="us20")

print(f"Base dataset loaded with {len(df)} polls and {len(df.columns)} features.\n")
print(df.info())
df.head()
# Out:
# Base dataset loaded with 7470 polls and 21 features.
#
# <class 'pandas.DataFrame'>
# RangeIndex: 7470 entries, 0 to 7469
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      7470 non-null   str
#  1   author_id                     7470 non-null   str
#  2   created_at                    6698 non-null   str
#  3   tweet_text                    7470 non-null   str
#  4   data_source                   7470 non-null   str
#  5   duration_minutes              7028 non-null   float64
#  6   n_options                     7470 non-null   int64
#  7   total_votes                   7470 non-null   int64
#  8   poll_options                  7470 non-null   str
#  9   user_id                       6318 non-null   str
#  10  author_partisanship_raw       6318 non-null   float64
#  11  author_partisanship           6318 non-null   float64
#  12  user_id_demo                  2897 non-null   str
#  13  author_org_prob               2897 non-null   float64
#  14  author_gender_male            2897 non-null   float64
#  15  author_age_under_29           2897 non-null   float64
#  16  author_age_30_39              2897 non-null   float64
#  17  author_age_40_over            2897 non-null   float64
#  18  audience_mean_partisanship    3360 non-null   float64
#  19  audience_median_partisanship  3360 non-null   float64
#  20  audience_n_distinct_users     7470 non-null   int64
# dtypes: float64(10), int64(3), str(8)
# memory usage: 1.2 MB
# None
#               tweet_id            author_id                      created_at  \
# 0  1221361006535790592  1100725849358303235  Sun Jan 26 09:15:30 +0000 2020
# 1  1222264765373919232   778093671254204416  Tue Jan 28 21:06:43 +0000 2020
# 2  1221625424255602690  1010164874285068288  Mon Jan 27 02:46:12 +0000 2020
# 3  1215101575322046464            586180854  Thu Jan 09 02:42:45 +0000 2020
# 4  1223290958889881601   779203152637669376  Fri Jan 31 17:04:26 +0000 2020
#
#                                           tweet_text data_source  \
# 0  Who Will 2020 United States PRESIDENTIAL ELECT...    decahose
# 1         Who will win the Presidential election? 🇺🇸    decahose
# 2  Which of the following actually has envisioned...    decahose
# 3  If the election were today who would you vote ...    decahose
# 4  So just a single poll now based on https://t.c...    decahose
#
#    duration_minutes  n_options  total_votes  \
# 0           10080.0          4            2
# 1           10080.0          4           16
# 2            1440.0          4          108
# 3            1440.0          4          452
# 4           10080.0          4           63
#
#                                         poll_options              user_id  \
# 0  [{'position': 1, 'label': 'Donald Trump', 'vot...  1100725849358303235
# 1  [{'position': 1, 'label': 'Bernie Sanders', 'v...   778093671254204416
# 2  [{'position': 1, 'label': 'Bernie Sanders', 'v...  1010164874285068288
# 3  [{'position': 1, 'label': 'Biden', 'votes': 53...            586180854
# 4  [{'position': 1, 'label': 'Biden', 'votes': 0}...   779203152637669376
#
#    ...  author_partisanship         user_id_demo author_org_prob  \
# 0  ...             0.796107  1100725849358303235          0.0015
# 1  ...             1.495457                  NaN             NaN
# 2  ...             2.335044                  NaN             NaN
# 3  ...             1.145222                  NaN             NaN
# 4  ...            -0.468588                  NaN             NaN
#
#    author_gender_male  author_age_under_29  author_age_30_39  \
# 0              0.9946               0.2336            0.2219
# 1                 NaN                  NaN               NaN
# 2                 NaN                  NaN               NaN
# 3                 NaN                  NaN               NaN
# 4                 NaN                  NaN               NaN
#
#    author_age_40_over  audience_mean_partisanship  \
# 0              0.5446                         NaN
# 1                 NaN                         NaN
# 2                 NaN                   -0.753739
# 3                 NaN                         NaN
# 4                 NaN                         NaN
#
#    audience_median_partisanship  audience_n_distinct_users
# 0                           NaN                          0
# 1                           NaN                          0
# 2                     -0.664441                          9
# 3                           NaN                          0
# 4                           NaN                          0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 2. Poll Sources and Distribution

# %%
source_counts = df['data_source'].value_counts()

plt.figure(figsize=(8, 5))
sns.barplot(x=source_counts.index, y=source_counts.values, palette='viridis')
plt.title('Distribution of Polls by Data Source (US20)')
plt.ylabel('Number of Polls')
plt.xlabel('Source')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['total_votes'].dropna(), bins=50, log_scale=True, color="skyblue")
plt.title('Distribution of Total Votes per Poll (Log Scale - US20)')
plt.xlabel('Total Votes (Log10)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 3. Author Partisanship

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['author_partisanship'].dropna(), bins=50, color="coral", kde=True)
plt.title('Distribution of Author Partisanship (Z-Score - US20)')
plt.xlabel('Author Partisanship (Negative=Liberal, Positive=Conservative)')
plt.ylabel('Frequency')
plt.axvline(0, color='gray', linestyle='--')
plt.show()

# %% [markdown]
# ## 4. Audience Partisanship
#
# Analyzing the distribution of the mean partisanship scores of the audience (retweeters/favoriters).

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['audience_mean_partisanship'].dropna(), bins=50, color="mediumseagreen", kde=True)
plt.title('Distribution of Audience Mean Partisanship (Raw - US20)')
plt.xlabel('Audience Mean Partisanship Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 5. Author vs Audience Partisanship
#
# Relationship between the poll author's inferred partisanship and their audience's mean partisanship.

# %%
plot_df = df.dropna(subset=['author_partisanship', 'audience_mean_partisanship'])

plt.figure(figsize=(8, 8))
sns.scatterplot(data=plot_df, x='author_partisanship', y='audience_mean_partisanship', alpha=0.3)
plt.title('Author Partisanship vs Audience Mean Partisanship (US20)')
plt.xlabel('Author Partisanship (Z-score)')
plt.ylabel('Audience Mean Partisanship (Raw)')
plt.axvline(0, color='gray', linestyle='--', alpha=0.5)
plt.show()
